# %%
import fiona

# %%
shape = fiona.open(r"C:\Users\Andrew\Desktop\becode_projects\3D-Houses\DHMVIIDSMRAS1m_k01\DHMVII_vdc_k01\DHMVII_vdc_k01.shp")
print(shape.schema)
# Out:
# {'properties': OrderedDict([('Id', 'int:6'), ('OpnDatum1', 'date'), ('OpnDatum2', 'date')]), 'geometry': '3D Polygon'}

# %%
#first feature of the shapefile
first = shape.next()
print(first) # (GeoJSON format)
# Out:
# {'type': 'Feature', 'id': '0', 'properties': OrderedDict([('Id', 0), ('OpnDatum1', '2013-02-20'), ('OpnDatum2', None)]), 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[(162079.0100390613, 238604.76999878138, 0.0), (162098.55007813126, 238604.11000274494, 0.0), (162099.80984375626, 238605.04999755695, 0.0), (162099.99985607713, 238609.5300009176, 0.0), (162099.99992141128, 238605.86000366136, 0.0), (162099.99991637468, 238600.73001953587, 0.0), (162099.9999263212, 238599.4500073269, 0.0), (162099.9999173805, 238583.15000427142, 0.0), (162099.99991682172, 238575.62999267876, 0.0), (162099.9999158308, 238561.35000121966, 0.0), (162099.9999171421, 238561.21000976488, 0.0), (162099.99992598593, 238560.4899987802, 0.0), (162099.9999215901, 238553.46999633312, 0.0), (162099.9999134466, 238530.71998901293, 0.0), (162099.9999116361, 238523.87000549585, 0.0), (162099.99991690367, 238518.23999877647, 0.0), (162099.99992281944, 238515.9900006093, 0.0), (162099.99992214888, 238515.1500122
# ...

# %%
shape_x = fiona.open(r"C:\Users\Andrew\Desktop\becode_projects\3D-Houses\DHMVIIDSMRAS1m_k01\DHMVII_vdc_k01\DHMVII_vdc_k01.shx")
print(shape_x.schema)
# Out:
# {'properties': OrderedDict([('Id', 'int:6'), ('OpnDatum1', 'date'), ('OpnDatum2', 'date')]), 'geometry': '3D Polygon'}

# %%
#first feature of the shapefile
first = shape_x.next()
print(first) # (GeoJSON format)
# Out:
# {'type': 'Feature', 'id': '0', 'properties': OrderedDict([('Id', 0), ('OpnDatum1', '2013-02-20'), ('OpnDatum2', None)]), 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[(162079.0100390613, 238604.76999878138, 0.0), (162098.55007813126, 238604.11000274494, 0.0), (162099.80984375626, 238605.04999755695, 0.0), (162099.99985607713, 238609.5300009176, 0.0), (162099.99992141128, 238605.86000366136, 0.0), (162099.99991637468, 238600.73001953587, 0.0), (162099.9999263212, 238599.4500073269, 0.0), (162099.9999173805, 238583.15000427142, 0.0), (162099.99991682172, 238575.62999267876, 0.0), (162099.9999158308, 238561.35000121966, 0.0), (162099.9999171421, 238561.21000976488, 0.0), (162099.99992598593, 238560.4899987802, 0.0), (162099.9999215901, 238553.46999633312, 0.0), (162099.9999134466, 238530.71998901293, 0.0), (162099.9999116361, 238523.87000549585, 0.0), (162099.99991690367, 238518.23999877647, 0.0), (162099.99992281944, 238515.9900006093, 0.0), (162099.99992214888, 238515.1500122
# ...
